# %%
from ultralytics import YOLO

# %%
model = YOLO("best.pt")

# %%
# Predict on image
results = model.predict(
    source=r"E:\COMPLETED PROJECTS\Helmet\Test Images\img_4.jpg",   # put your image path here
    conf=0.3,            # confidence threshold
    show=True,           # show output window
    save=False            # save output in runs/predict
)
# Out:
# image 1/1 E:\COMPLETED PROJECTS\Helmet\Test Images\img_4.jpg: 640x416 (no detections), 263.0ms
# Speed: 5.4ms preprocess, 263.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 416)

# %%
results[0].show()
